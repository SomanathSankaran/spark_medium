# %%
import pandas as pd

# %%
from pyhive import hive

# %%
connection=hive.connect(host='localhost')

# %%
df_tables=pd.read_sql(con=connection,sql="show tables")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-50-8e330faf8655> in <module>()
# ----> 1 df_tables=pd.read_sql(con=connection,sql="show tables")
#
# /home/somanath/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# /home/somanath/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# /home/somanath/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#    1411                                    " to rollback" % (args[0], exc))
# -> 1412                 raise_with_traceback(ex)
#    1413
#    1414             ex = DatabaseError(
#
# /home/somanath/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1406         except Exception as exc:
#    1407             try:
# -> 1408                 self.con.rollback()
#    1409             except Exception:  # pragma: no cover
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#
# /home/somanath/anaconda2/lib/python2.7/site-packages/pyhive/hive.pyc in rollback(self)
#     240
#     241     def rollback(self):
# --> 242         raise NotSupportedError("Hive does not have transactions")  # pragma: no cover
#     243
#     244
#
# DatabaseError: Execution failed on sql: show tables
# TExecuteStatementResp(status=TStatus(errorCode=0, errorMessage=u"org.apache.spark.sql.AnalysisException: Table or view not found: `defaut`.`air_det`; line 1 pos 14;\n'GlobalLimit 10\n+- 'LocalLimit 10\n   +- 'Project [*]\n      +- 'UnresolvedRelation `defaut`.`air_det`\n", sqlState=None, infoMessages=[u"*org.apache.hive.service.cli.HiveSQLException:org.apache.spark.sql.AnalysisException: Table or view not found: `defaut`.`air_det`; line 1 pos 14;\n'GlobalLimit 10\n+- 'LocalLimit 10\n   +- 'Project [*]\n      +- 'UnresolvedRelation `defaut`.`air_det`\n:28:27", u'org.apache.spark.sql.hive.thriftserver.SparkExecuteStatementOperation:org$apache$spark$sql$hive$thriftserver$SparkExecuteStatementOperation$$execute:SparkExecuteStatementOperation.scala:269', u'org.apache.spark.sql.hive.thriftserver.SparkExecuteStatementOperation:runInternal:SparkExecuteStatementOperation.scala:162', u'org.apache.hive.service.cli.operation.Operation:run:Operation.java:257', u'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatementInternal:HiveSessionImpl.java:470', u'org.apache.hive.service.cli.session.HiveSessionImpl:executeStatement:HiveSessionImpl.java:451', u'sun.reflect.NativeMethodAccessorImpl:invoke0:NativeMethodAccessorImpl.java:-2', u'sun.reflect.NativeMethodAccessorImpl:invoke:NativeMethodAccessorImpl.java:62', u'sun.reflect.DelegatingMethodAccessorImpl:invoke:DelegatingMethodAccessorImpl.java:43', u'java.lang.reflect.Method:invoke:Method.java:498', u'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:78', u'org.apache.hive.service.cli.session.HiveSessionProxy:access$000:HiveSessionProxy.java:36', u'org.apache.hive.service.cli.session.HiveSessionProxy$1:run:HiveSessionProxy.java:63', u'java.security.AccessController:doPrivileged:AccessController.java:-2', u'javax.security.auth.Subject:doAs:Subject.java:422', u'org.apache.hadoop.security.UserGroupInformation:doAs:UserGroupInformation.java:1698', u'org.apache.hive.service.cli.session.HiveSessionProxy:invoke:HiveSessionProxy.java:59', u'com.sun.proxy.$Proxy23:executeStatement::-1', u'org.apache.hive.service.cli.CLIService:executeStatement:CLIService.java:262', u'org.apache.hive.service.cli.thrift.ThriftCLIService:ExecuteStatement:ThriftCLIService.java:437', u'org.apache.hive.service.cli.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1313', u'org.apache.hive.service.cli.thrift.TCLIService$Processor$ExecuteStatement:getResult:TCLIService.java:1298', u'org.apache.thrift.ProcessFunction:process:ProcessFunction.java:39', u'org.apache.thrift.TBaseProcessor:process:TBaseProcessor.java:39', u'org.apache.hive.service.auth.TSetIpAddressProcessor:process:TSetIpAddressProcessor.java:53', u'org.apache.thrift.server.TThreadPoolServer$WorkerProcess:run:TThreadPoolServer.java:286', u'java.util.concurrent.ThreadPoolExecutor:runWorker:ThreadPoolExecutor.java:1149', u'java.util.concurrent.ThreadPoolExecutor$Worker:run:ThreadPoolExecutor.java:624', u'java.lang.Thread:run:Thread.java:748'], statusCode=3), operationHandle=None)
# unable to rollback

# %%
df_tables
# Out:
#    database        tableName  isTemporary
# 0   default          air_det        False
# 1   default       arry_table        False
# 2   default              art        False
# 3   default             art2        False
# 4   default         dataset1        False
# 5   default    dataset1_buck        False
# 6   default         dataset2        False
# 7   default    dataset2_buck        False
# 8   default          employe        False
# 9   default         employee        False
# 10  default   employee_mysql        False
# 11  default  hivewrite_table        False
# 12  default               id        False
# 13  default           intest        False
# 14  default             soma        False
# 15  default            soma1        False
# 16  default        sparkhive        False
# 17  default              ss1        False
# 18  default             sss1        False
# 19  default    streaming_log        False
# 20  default             test        False
# 21  default            test1        False
# 22  default            test2        False
# 23  default        testtable        False
# 24  default           testtt        False
# 25  default            tewst        False
# 26  default                u        False
# 27  default               u1        False
# 28  default              u1u        False
# 29  default             u1u1        False
# 30  default          windows        False

# %%
df_query=pd.read_sql_query(con=connection,sql="select * from air_det limit 10")

# %%
df_query
# Out:
#    Year Month DayofMonth DayOfWeek DepTime CRSDepTime ArrTime CRSArrTime  \
# 0  2008     1          3         4    2003       1955    2211       2225
# 1  2008     1          3         4     712        710     953       1000
# 2  2008     1          3         4    1450       1435    1806       1745
# 3  2008     1          3         4     831        830     935        955
# 4  2008     1          3         4    1528       1510    1802       1810
# 5  2008     1          3         4    1620       1620    1639       1655
# 6  2008     1          3         4    1008       1005    1234       1255
# 7  2008     1          3         4     754        735    1002       1000
# 8  2008     1          3         4    1749       1725    2019       2030
# 9  2008     1          3         4     706        700     916        915
#
#   UniqueCarrier lightNum      ...      Cancelled CancellationCode Diverted  \
# 0            WN      335      ...              0             None        0
# 1            WN     1112      ...              0             None        0
# 2            WN     3244      ...              0             None        0
# 3            WN      300      ...              0             None        0
# 4            WN     3858      ...              0             None        0
# 5            WN      810      ...              0             None        0
# 6            WN      543      ...              0             None        0
# 7            WN     3231      ...              0             None        0
# 8            WN     2175      ...              0             None        0
# 9            WN      100      ...              0             None        0
#
#   CarrierDelay WeatherDelay NASDelay SecurityDelay LateAircraftDelay  UUID  \
# 0           NA           NA       NA            NA                NA   0-0
# 1           NA           NA       NA            NA                NA  0-32
# 2            0            0        6             0                15  0-48
# 3           NA           NA       NA            NA                NA  0-36
# 4           NA           NA       NA            NA                NA  0-45
# 5           NA           NA       NA            NA                NA   0-9
# 6           NA           NA       NA            NA                NA  0-31
# 7           NA           NA       NA            NA                NA   0-1
# 8           NA           NA       NA            NA                NA  0-41
# 9           NA           NA       NA            NA                NA  0-10
#
#   unixtimeStamp
# 0    2017-11-26
# 1    2017-11-26
# 2    2017-11-26
# 3    2017-11-26
# 4    2017-11-26
# 5    2017-11-26
# 6    2017-11-26
# 7    2017-11-26
# 8    2017-11-26
# 9    2017-11-26
#
# [10 rows x 31 columns]
